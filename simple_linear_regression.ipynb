# %% [markdown]
# # Simple Linear Regression

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
salary = pd.read_csv('Salary_data.csv')
X = salary.iloc[:,:-1].values
y = salary.iloc[:,-1].values
salary.head()
y
# Out:
# array([ 39343.,  46205.,  37731.,  43525.,  39891.,  56642.,  60150.,
#         54445.,  64445.,  57189.,  63218.,  55794.,  56957.,  57081.,
#         61111.,  67938.,  66029.,  83088.,  81363.,  93940.,  91738.,
#         98273., 101302., 113812., 109431., 105582., 116969., 112635.,
#        122391., 121872.])

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=2)

# %%
from sklearn.linear_model import LinearRegression
lr = LinearRegression()
lr.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
y_pred = lr.predict(X_test)

# %%
plt.scatter(X_train, y_train, color = 'red')
plt.plot(X_train, lr.predict(X_train), color = 'blue')
plt.title('Salary Vs Experience(Training Set)')
plt.xlabel('Years of Experience(Training Set)')
plt.ylabel('Salary')
plt.show()

# %%
plt.scatter(X_test, y_test, color = 'red')
plt.plot(X_train, lr.predict(X_train), color = 'blue')
plt.title('Salary Vs Experience(Test Set)')
plt.xlabel('Years of Experience(Test Set)')
plt.ylabel('Salary')
plt.show()

# %%
print(f'Predicted salary for person with experience of 12 years : {lr.predict([[12]])}')
# Out:
# Predicted salary for person with experience of 12 years : [139228.21177714]

# %%
print(lr.coef_)
print(lr.intercept_)
print(f'Salary={(lr.coef_).round(2)}×YearsExperience+ {(lr.intercept_).round(2)}')
# Out:
# [9569.58688543]
# 24393.16915194835
# Salary=[9569.59]×YearsExperience+ 24393.17
